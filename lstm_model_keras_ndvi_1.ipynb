# %% [markdown]
# <a href="https://colab.research.google.com/github/pablex72/LSTM-neural/blob/main/lstm_model_keras_ndvi_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##  https://docs.google.com/spreadsheets/d/e/2PACX-1vSQzmvAxZgaIZKxFVXjZT8HWE6swuxCaXHBhOWS131Hq1Fc8FtjhTVS-55HWesL-4M5ANqX2wuutCi4/pub?gid=555765906&single=true&output=csv

# %%
import numpy as np
np.random.seed(4)
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
#
# Funciones auxiliares
#

dataset = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSQzmvAxZgaIZKxFVXjZT8HWE6swuxCaXHBhOWS131Hq1Fc8FtjhTVS-55HWesL-4M5ANqX2wuutCi4/pub?gid=555765906&single=true&output=csv', index_col='system:time_start', parse_dates=['system:time_start'])
dataset.head()
dataset
# Out:
#                    After cloud filter
# system:time_start
# 2018-09-03                     748.00
# 2018-09-08                     768.00
# 2018-09-10                        NaN
# 2018-09-13                     682.00
# 2018-09-18                     694.00
# ...                               ...
# 2022-08-28                     134.00
# 2022-09-04                     126.00
# 2022-09-12                     124.00
# 2022-09-19                       0.11
# 2022-09-22                      99.00
#
# [169 rows x 1 columns]
